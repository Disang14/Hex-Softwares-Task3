# %% [markdown]
# # Covid-19 Data Analysis Project

# %%
#Importing useful libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#Loading data
df=pd.read_csv('day_wise.csv')

# %%
#Exploring the columns in the data
df.columns
# Out:
# Index(['Date', 'Confirmed', 'Deaths', 'Recovered', 'Active', 'New cases',
#        'New deaths', 'New recovered', 'Deaths / 100 Cases',
#        'Recovered / 100 Cases', 'Deaths / 100 Recovered', 'No. of countries'],
#       dtype='object')

# %%
#Exploring first 5 observations in the data
df.head()
# Out:
#          Date  Confirmed  Deaths  Recovered  Active  New cases  New deaths  \
# 0  2020-01-22        555      17         28     510          0           0
# 1  2020-01-23        654      18         30     606         99           1
# 2  2020-01-24        941      26         36     879        287           8
# 3  2020-01-25       1434      42         39    1353        493          16
# 4  2020-01-26       2118      56         52    2010        684          14
#
#    New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0              0                3.06                   5.05
# 1              2                2.75                   4.59
# 2              6                2.76                   3.83
# 3              3                2.93                   2.72
# 4             13                2.64                   2.46
#
#    Deaths / 100 Recovered  No. of countries
# 0                   60.71                 6
# 1                   60.00                 8
# ...

# %%
#Exploring last 5 observations in the data
df.tail()
# Out:
#            Date  Confirmed  Deaths  Recovered   Active  New cases  New deaths  \
# 144  2020-06-14    7911685  433375    3715556  3762754     133545        3344
# 145  2020-06-15    8033720  436883    3794955  3801882     122035        3508
# 146  2020-06-16    8173199  443669    3892350  3837180     139479        6786
# 147  2020-06-17    8349209  448943    4009755  3890511     176010        5274
# 148  2020-06-18    8488235  453965    4090382  3943888     139026        5022
#
#      New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 144          69958                5.48                  46.96
# 145          79399                5.44                  47.24
# 146          97395                5.43                  47.62
# 147         117405                5.38                  48.03
# 148          80627                5.35                  48.19
#
#      Deaths / 100 Recovered  No. of countries
# 144                   11.66               187
# ...

# %%
#Observing total number of rows and columns
df.shape
# Out:
# (149, 12)

# %%
#Exploring more information about the datasdet
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149 entries, 0 to 148
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Date                    149 non-null    object
#  1   Confirmed               149 non-null    int64
#  2   Deaths                  149 non-null    int64
#  3   Recovered               149 non-null    int64
#  4   Active                  149 non-null    int64
#  5   New cases               149 non-null    int64
#  6   New deaths              149 non-null    int64
#  7   New recovered           149 non-null    int64
#  8   Deaths / 100 Cases      149 non-null    float64
#  9   Recovered / 100 Cases   149 non-null    float64
#  10  Deaths / 100 Recovered  149 non-null    float64
#  11  No. of countries        149 non-null    int64
# dtypes: float64(3), int64(8), object(1)
# memory usage: 14.1+ KB

# %%
#Descriptive statistics measures
df.describe()
# Out:
#           Confirmed         Deaths     Recovered        Active      New cases  \
# count  1.490000e+02     149.000000  1.490000e+02  1.490000e+02     149.000000
# mean   2.354361e+06  146198.563758  8.880001e+05  1.320162e+06   57124.791946
# std    2.604012e+06  156983.359721  1.149673e+06  1.331511e+06   47264.714711
# min    5.550000e+02      17.000000  2.800000e+01  5.100000e+02       0.000000
# 25%    8.336500e+04    2866.000000  3.669500e+04  5.098400e+04    3159.000000
# 50%    1.250387e+06   73017.000000  2.559820e+05  9.213880e+05   73676.000000
# 75%    4.267506e+06  292303.000000  1.453740e+06  2.521463e+06   92642.000000
# max    8.488235e+06  453965.000000  4.090382e+06  3.943888e+06  176010.000000
#
#         New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# count   149.000000     149.000000          149.000000             149.000000
# mean   3046.630872   27452.040268            4.938523              29.885906
# ...

# %%
#Confirming if there are missing values
df.isnull().sum()
# Out:
# Date                      0
# Confirmed                 0
# Deaths                    0
# Recovered                 0
# Active                    0
# New cases                 0
# New deaths                0
# New recovered             0
# Deaths / 100 Cases        0
# Recovered / 100 Cases     0
# Deaths / 100 Recovered    0
# No. of countries          0
# dtype: int64

# %% [markdown]
# ### Exploring The Relationship Among Variables Using Scatterplots

# %%
sns.relplot(x="Confirmed",y="Deaths",data=df,)

# %%
sns.relplot(x="Confirmed",y="Recovered",data=df)

# %%
sns.relplot(x="Confirmed",y="Active",data=df)

# %%
sns.relplot(x="New cases",y="New deaths",data=df)

# %%
sns.relplot(x="New cases",y="New recovered",data=df)

# %%
# Pair plots
sns.pairplot(df)
plt.show()

# %%
sns.relplot(x="Confirmed",y="Recovered", kind='line',data=df)

# %%
sns.relplot(x="Confirmed",y="Deaths",kind='line',data=df,)
